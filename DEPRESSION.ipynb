# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data

data =pd.read_csv('b_depressed.csv')
data.head()
# Out:
#    Survey_id  Ville_id  sex  Age  Married  Number_children  education_level  \
# 0        926        91    1   28        1                4               10
# 1        747        57    1   23        1                3                8
# 2       1190       115    1   22        1                3                9
# 3       1065        97    1   27        1                2               10
# 4        806        42    0   59        0                4               10
#
#    total_members  gained_asset  durable_asset  ...  incoming_salary  \
# 0              5      28912201       22861940  ...                0
# 1              5      28912201       22861940  ...                0
# 2              5      28912201       22861940  ...                0
# 3              4      52667108       19698904  ...                0
# 4              6      82606287       17352654  ...                1
#
#    incoming_own_farm  incoming_business  incoming_no_business  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1429 entries, 0 to 1428
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Survey_id              1429 non-null   int64
#  1   Ville_id               1429 non-null   int64
#  2   sex                    1429 non-null   int64
#  3   Age                    1429 non-null   int64
#  4   Married                1429 non-null   int64
#  5   Number_children        1429 non-null   int64
#  6   education_level        1429 non-null   int64
#  7   total_members          1429 non-null   int64
#  8   gained_asset           1429 non-null   int64
#  9   durable_asset          1429 non-null   int64
#  10  save_asset             1429 non-null   int64
#  11  living_expenses        1429 non-null   int64
#  12  other_expenses         1429 non-null   int64
#  13  incoming_salary        1429 non-null   int64
#  14  incoming_own_farm      1429 non-null   int64
# ...

# %%
data.describe()
# Out:
#         Survey_id     Ville_id          sex          Age      Married  \
# count  1429.00000  1429.000000  1429.000000  1429.000000  1429.000000
# mean    715.00000    76.286214     0.918125    34.777467     0.772568
# std     412.66108    66.444012     0.274271    13.986219     0.419320
# min       1.00000     1.000000     0.000000    17.000000     0.000000
# 25%     358.00000    24.000000     1.000000    25.000000     1.000000
# 50%     715.00000    57.000000     1.000000    30.000000     1.000000
# 75%    1072.00000   105.000000     1.000000    42.000000     1.000000
# max    1429.00000   292.000000     1.000000    91.000000     1.000000
#
#        Number_children  education_level  total_members  gained_asset  \
# count      1429.000000      1429.000000    1429.000000  1.429000e+03
# mean          2.883135         8.687194       4.969209  3.363448e+07
# std           1.874472         2.923532       1.786317  2.003854e+07
# ...

# %%
data.shape
# Out:
# (1429, 23)

# %%
# Explore Target distribution 
sns.catplot(x="depressed", kind="count", data=data)
plt.xticks([0, 1], ['Not Depressed', 'Depressed'])
plt.show()

# %%
Gender_succeptibility = sns.countplot(x='sex', hue='depressed', data=data, palette='Set2')
plt.xticks([0, 1], ['Female', 'Male'])


plt.title('Sex Distribution Succeptibility to Depression')
plt.legend(['Not depressed', 'Depressed'])


plt.show()

# %%
##Age_succeptibility = sns.countplot(x='Age', hue='depressed', data=data, palette='Set2')
##plt.xticks([0, 1], ['Young', 'Adult'])


##plt.title('Age Distribution Succeptibility to Depressed')
##plt.legend(['Not Depressed', 'Depressed'])


##plt.show()

# %%
sns.set(rc= {'figure.figsize': (20,8)})
sns.heatmap(data.corr(), annot = True, linewidths=.5, cmap="Blues")

plt.title('Correlation Between Variables', fontsize = 20)

plt.show()

# %%
data.isnull().sum()
# Out:
# Survey_id                 0
# Ville_id                  0
# sex                       0
# Age                       0
# Married                   0
# Number_children           0
# education_level           0
# total_members             0
# gained_asset              0
# durable_asset             0
# save_asset                0
# living_expenses           0
# other_expenses            0
# incoming_salary           0
# incoming_own_farm         0
# incoming_business         0
# incoming_no_business      0
# incoming_agricultural     0
# farm_expenses             0
# labor_primary             0
# lasting_investment        0
# no_lasting_investmen     20
# depressed                 0
# dtype: int64

# %%
data.drop(columns='no_lasting_investmen', inplace=True)

# %%
data.isnull().sum()
# Out:
# Survey_id                0
# Ville_id                 0
# sex                      0
# Age                      0
# Married                  0
# Number_children          0
# education_level          0
# total_members            0
# gained_asset             0
# durable_asset            0
# save_asset               0
# living_expenses          0
# other_expenses           0
# incoming_salary          0
# incoming_own_farm        0
# incoming_business        0
# incoming_no_business     0
# incoming_agricultural    0
# farm_expenses            0
# labor_primary            0
# lasting_investment       0
# depressed                0
# dtype: int64

# %%
X = data.drop(['Survey_id'], axis=1,)
y = data['Survey_id']

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mean_absolute_error(y_test,logistic_prediction)
# Out:
# 460.4475524475524

# %%
mean_squared_error(y_test, logistic_prediction)
# Out:
# 321641.2727272727

# %%
np.sqrt(mean_squared_error(y_test, logistic_prediction))
# Out:
# 567.1342634044188

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTR= DecisionTreeRegressor()

# %%
DTR.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
DT= DTR.predict(X_test)

# %%
mean_absolute_error(y_test,DT)
# Out:
# 291.81468531468533

# %%
np.sqrt(mean_absolute_error(y_test,DT))
# Out:
# 17.082584269210713

# %%
import pickle
filename= 'Depression_predict.sav'
pickle.dump(DTR, open(filename, 'wb'))
